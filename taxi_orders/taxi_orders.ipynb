# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# ### Описание задачи:

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.

# %% [markdown]
# ### Цель:
#
# Протестировать и подобрать оптимальную модель для прогнозирования количества заказов такси в будущий час.

# %% [markdown]
# ## Подготовка

# %%
# импорт Pandas
import pandas as pd

# импорт Os для работы с файлами и каталогами
import os

# импорт Numpy
import numpy as np

import datetime

# импорт matplotlib для управления графиками
import matplotlib.pyplot as plt

# импорт Sklearn

from sklearn.model_selection import train_test_split, TimeSeriesSplit, RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# импорт Catboost

from catboost import CatBoostRegressor

# импорт LightGBM

from lightgbm import LGBMRegressor

# импорт Seasonal

from statsmodels.tsa.seasonal import seasonal_decompose

pd.options.display.float_format = '{:,.2f}'.format
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-89497dc80a8b> in <module>
#      24 # импорт Catboost
#      25
# ---> 26 from catboost import CatBoostRegressor
#      27
#      28 # импорт LightGBM
#
# ModuleNotFoundError: No module named 'catboost'

# %%
# напишем функцию для комфортной загрузки датасетов и локально, и с сервера

def file_loader(pth1, pth2):
    if os.path.exists(pth1):
        return pd.read_csv(pth1)
    elif os.path.exists(pth2):
        return pd.read_csv(pth2)
    else:
        print('Check the path')

# %%
df = file_loader('taxi.csv', '/datasets/taxi.csv')

# %%
df.head(15)
# Out:
#                datetime  num_orders
# 0   2018-03-01 00:00:00           9
# 1   2018-03-01 00:10:00          14
# 2   2018-03-01 00:20:00          28
# 3   2018-03-01 00:30:00          20
# 4   2018-03-01 00:40:00          32
# 5   2018-03-01 00:50:00          21
# 6   2018-03-01 01:00:00           7
# 7   2018-03-01 01:10:00           5
# 8   2018-03-01 01:20:00          17
# 9   2018-03-01 01:30:00          12
# 10  2018-03-01 01:40:00          19
# 11  2018-03-01 01:50:00          25
# 12  2018-03-01 02:00:00          22
# 13  2018-03-01 02:10:00          12
# 14  2018-03-01 02:20:00          19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26496 entries, 0 to 26495
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    26496 non-null  object
#  1   num_orders  26496 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 414.1+ KB

# %%
df['datetime'] = df['datetime'].astype('datetime64')
df = df.set_index('datetime')

# %%
df.describe()
# Out:
#        num_orders
# count   26,496.00
# mean        14.07
# std          9.21
# min          0.00
# 25%          8.00
# 50%         13.00
# 75%         19.00
# max        119.00

# %%
df.sort_index(inplace=True)
df = df.resample('1H').sum()
df
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43
# ...                         ...
# 2018-08-31 19:00:00         136
# 2018-08-31 20:00:00         154
# 2018-08-31 21:00:00         159
# 2018-08-31 22:00:00         223
# 2018-08-31 23:00:00         205
#
# [4416 rows x 1 columns]

# %% [markdown]
# #### Вывод:
#
# Данные в хорошем состоянии и готовы для анализа и последующих операций

# %% [markdown]
# ## Анализ

# %% [markdown]
# Посмотрим на график распределения заказов по времени.

# %%
df.plot(figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Из данного график сложно сделать какие-либо выводы, кроме того, что количество заказов такси сильно колеблется в течении времени, а также, что количество заказов в час к концу лета увеличилось<br/>
#
# Для выявления закономерностей произведем декомпозицию.

# %%
df_decomposed = seasonal_decompose(df)
df_decomposed.trend.plot(figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Из графика тренда можно сделать однозначный вывод, что ежечасное количество заказов у данного оператора такси на протяжении всего анализируемого периода времени растет. Это говорит о росте популярности данного сервиса и стабильном развитии бизнеса. <br/>
# Также данный рост может быть связан с сезонными явлениями годового масштаба (например, весной заказов меньше чем летом, а пик наблюдается в сентябре, а потом все опять снижается к зиме). Но для проверки данной гипотезы нам не хватает данных - нужны данные хотя бы за 2 года.
# <br/>
# Также в колебаниях графика в течение месяца можно увидеть некую повторяемость. На ежедневные колебания они не похожи, возможно есть некая зависимость количества заказов от дня недели. Проверим эту гипотезу чуть позже.
# <br/>
# Рост продаж подтверждает и график скользящей средней.

# %%
# месячное усреднение
df.rolling(720).mean().plot(figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Видим, что среднемесячное количество заказов в час за анализируемый период выросло более чем в 2 раза.

# %%
# месячное усреднение
df.rolling(24).mean().plot(figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Среднедневное количество заказов колеблется сильнее.<br/>
#
# Проанализируем колебания и попытаемся найти в них закономерности.

# %%
df_decomposed.seasonal.plot(figsize=(15, 5), xlim=('2018-03-02', '2018-03-03'))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Видим четкие колебания количества заказов в течение суток: наименьшее количество заказов с 4 до 8 утра, пик заказов приходится на период с 23.00 до 01.00. Такие колебания обусловлены тем, что люди предпочитают ночью спать. И если даже рейс ночью, они предпочитают выехать на него заранее, и поспать в аэропорте.

# %%
df_by_days = df.resample('1D').sum()
df_bd_dec = seasonal_decompose(df_by_days)
df_bd_dec.seasonal.plot(figsize=(15, 5), xlim=('2018-03-01', '2018-03-14'))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# На графике за период в 14 дней хорошо видно, что сезонность имеет период в 7 дней и очевидно зависит от дня недели. Однако из этого графика непонятно, в какие именно дни недели происходят те или иные колебания спроса на услуги такси. Построим для этого другой график.

# %%
plt.plot(df_by_days.index.dayofweek, df_bd_dec.seasonal);

# %% [markdown]
# Из графика видно, что наибольший спрос на такси в Воскресенье (0) и Четверг (4), а наименьший в Понедельник и Субботу, причем колебания довольно существенные.

# %%
df_decomposed.resid.plot(figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# На графике с шумами видим некоторое количество больших пиков в положительную стороны, что говорит о наличии случайных факторов, влияющих на количество заказов (например, международная выставка или чемпионат по футболу).

# %% [markdown]
# #### Вывод:
#
# В исторических данных по заказам такси имеется четкая сезонная зависимость от времени суток и дня недели. Также имеется четкий тренд на увеличение заказов от месяца к месяцу. В данных присутствует определенное количество шумов, которые могут объясняться влиением случайных факторов.

# %% [markdown]
# ## Обучение

# %% [markdown]
# Чтобы было чему обучать моделей), создадим для них признаки.

# %%
# добавим календарные признаки

df['day'] = df.index.day
df['hour'] = df.index.hour
df['dayofweek'] = df.index.dayofweek
df['month'] = df.index.month
df
# Out:
#                      num_orders  day  hour  dayofweek  month
# datetime
# 2018-03-01 00:00:00         124    1     0          3      3
# 2018-03-01 01:00:00          85    1     1          3      3
# 2018-03-01 02:00:00          71    1     2          3      3
# 2018-03-01 03:00:00          66    1     3          3      3
# 2018-03-01 04:00:00          43    1     4          3      3
# ...                         ...  ...   ...        ...    ...
# 2018-08-31 19:00:00         136   31    19          4      8
# 2018-08-31 20:00:00         154   31    20          4      8
# 2018-08-31 21:00:00         159   31    21          4      8
# 2018-08-31 22:00:00         223   31    22          4      8
# 2018-08-31 23:00:00         205   31    23          4      8
#
# [4416 rows x 5 columns]

# %%
# добавим отстающие значения (lag)

n = 3
for i in range(1, n+1):
    name = 'lag_' + str(i)
    df[name] = df['num_orders'].shift(i, fill_value=0)
df
# Out:
#                      num_orders  day  hour  dayofweek  month  lag_1  lag_2  \
# datetime
# 2018-03-01 00:00:00         124    1     0          3      3      0      0
# 2018-03-01 01:00:00          85    1     1          3      3    124      0
# 2018-03-01 02:00:00          71    1     2          3      3     85    124
# 2018-03-01 03:00:00          66    1     3          3      3     71     85
# 2018-03-01 04:00:00          43    1     4          3      3     66     71
# ...                         ...  ...   ...        ...    ...    ...    ...
# 2018-08-31 19:00:00         136   31    19          4      8    207    217
# 2018-08-31 20:00:00         154   31    20          4      8    136    207
# 2018-08-31 21:00:00         159   31    21          4      8    154    136
# 2018-08-31 22:00:00         223   31    22          4      8    159    154
# 2018-08-31 23:00:00         205   31    23          4      8    223    159
#
#                      lag_3
# datetime
# 2018-03-01 00:00:00      0
# 2018-03-01 01:00:00      0
# 2018-03-01 02:00:00      0
# 2018-03-01 03:00:00    124
# 2018-03-01 04:00:00     85
# ...                    ...
# 2018-08-31 19:00:00    197
# 2018-08-31 20:00:00    217
# 2018-08-31 21:00:00    207
# 2018-08-31 22:00:00    136
# 2018-08-31 23:00:00    154
#
# [4416 rows x 8 columns]

# %%
# добавим скользящую среднюю

window = 3
df['rolling_mean'] = df['num_orders'].shift().rolling(window, min_periods=0).mean()
df = df.drop('2018-03-01 00:00:00')
df
# Out:
#                      num_orders  day  hour  dayofweek  month  lag_1  lag_2  \
# datetime
# 2018-03-01 01:00:00          85    1     1          3      3    124      0
# 2018-03-01 02:00:00          71    1     2          3      3     85    124
# 2018-03-01 03:00:00          66    1     3          3      3     71     85
# 2018-03-01 04:00:00          43    1     4          3      3     66     71
# 2018-03-01 05:00:00           6    1     5          3      3     43     66
# ...                         ...  ...   ...        ...    ...    ...    ...
# 2018-08-31 19:00:00         136   31    19          4      8    207    217
# 2018-08-31 20:00:00         154   31    20          4      8    136    207
# 2018-08-31 21:00:00         159   31    21          4      8    154    136
# 2018-08-31 22:00:00         223   31    22          4      8    159    154
# 2018-08-31 23:00:00         205   31    23          4      8    223    159
#
#                      lag_3  rolling_mean
# datetime
# 2018-03-01 01:00:00      0        124.00
# 2018-03-01 02:00:00      0        104.50
# 2018-03-01 03:00:00    124         93.33
# 2018-03-01 04:00:00     85         74.00
# 2018-03-01 05:00:00     71         60.00
# ...                    ...           ...
# 2018-08-31 19:00:00    197        207.00
# 2018-08-31 20:00:00    217        186.67
# 2018-08-31 21:00:00    207        165.67
# 2018-08-31 22:00:00    136        149.67
# 2018-08-31 23:00:00    154        178.67
#
# [4415 rows x 9 columns]

# %%
# выделим целевой признак и признаки

features = df.drop('num_orders', axis=1)
target = df['num_orders']

# %%
# разделим на обучающую и тестовую выборки

train_features, test_features, train_target, test_target = train_test_split(features, target, shuffle=False, test_size=0.1)
train_features
# Out:
#                      day  hour  dayofweek  month  lag_1  lag_2  lag_3  \
# datetime
# 2018-03-01 01:00:00    1     1          3      3    124      0      0
# 2018-03-01 02:00:00    1     2          3      3     85    124      0
# 2018-03-01 03:00:00    1     3          3      3     71     85    124
# 2018-03-01 04:00:00    1     4          3      3     66     71     85
# 2018-03-01 05:00:00    1     5          3      3     43     66     71
# ...                  ...   ...        ...    ...    ...    ...    ...
# 2018-08-13 09:00:00   13     9          0      8     91     39     66
# 2018-08-13 10:00:00   13    10          0      8    137     91     39
# 2018-08-13 11:00:00   13    11          0      8    156    137     91
# 2018-08-13 12:00:00   13    12          0      8    144    156    137
# 2018-08-13 13:00:00   13    13          0      8     92    144    156
#
#                      rolling_mean
# datetime
# 2018-03-01 01:00:00        124.00
# 2018-03-01 02:00:00        104.50
# 2018-03-01 03:00:00         93.33
# 2018-03-01 04:00:00         74.00
# 2018-03-01 05:00:00         60.00
# ...                           ...
# 2018-08-13 09:00:00         65.33
# 2018-08-13 10:00:00         89.00
# 2018-08-13 11:00:00        128.00
# 2018-08-13 12:00:00        145.67
# 2018-08-13 13:00:00        130.67
#
# [3973 rows x 8 columns]

# %% [markdown]
# Обучим известные нам модели и подберем оптимальные гиперпараметры

# %% [markdown]
# 1. Решающее дерево

# %%
# %%time

# используем RandomizedSearchCV для подбора параметров заменив в нем стандартный кросс-валидационный сплитер
# на специальный для временных рядов

tscv = TimeSeriesSplit()

model = DecisionTreeRegressor(random_state=1982)
depth_range = list(range(1, 31))
params = {'max_depth': depth_range}
tree_model = RandomizedSearchCV(model, params, scoring='neg_root_mean_squared_error', verbose=1, cv=tscv, random_state=1982)
tree_model.fit(train_features, train_target)
tree_best_params = tree_model.best_params_
tree_best_params
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Wall time: 822 ms
# {'max_depth': 8}

# %%
tree_model = DecisionTreeRegressor(**tree_best_params, random_state=1982)

# %% [markdown]
# 2. Случайный лес

# %%
# %%time

model = RandomForestRegressor(random_state=1982)
depth_range = list(range(1, 21))
est_range = list(range(1, 11))
params = {'max_depth': depth_range, 'n_estimators': est_range}
rf_model = RandomizedSearchCV(model, params, scoring='neg_root_mean_squared_error', verbose=1, cv=tscv, random_state=1982)
rf_model.fit(train_features, train_target)
rf_best_params = rf_model.best_params_
rf_best_params
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Wall time: 2.28 s
# {'n_estimators': 10, 'max_depth': 16}

# %%
rf_model = RandomForestRegressor(**rf_best_params, random_state=1982)

# %% [markdown]
# 3. Линейная регрессия

# %%
lr_model = LinearRegression()

# %% [markdown]
# 4. Catboost

# %%
# %%time

cb_model = CatBoostRegressor(random_state=1982, verbose=0)
depth_range = list(range(1, 11))
params = {'learning_rate': [0.03, 0.1, 0.5],
          'depth': depth_range,
          'iterations': [10, 100],
          'l2_leaf_reg': [1, 3, 5, 7, 9]}

grid_search_result = cb_model.grid_search(params, X=train_features, y=train_target, cv=tscv, plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# bestTest = 95.95788303
# bestIteration = 9
#
# 0:	loss: 95.9578830	best: 95.9578830 (0)	total: 175ms	remaining: 52.3s
#
# bestTest = 68.70808775
# bestIteration = 9
#
# 1:	loss: 68.7080877	best: 68.7080877 (1)	total: 184ms	remaining: 27.5s
#
# bestTest = 43.04217675
# bestIteration = 9
#
# 2:	loss: 43.0421767	best: 43.0421767 (2)	total: 193ms	remaining: 19.2s
#
# bestTest = 95.98173302
# bestIteration = 9
#
# 3:	loss: 95.9817330	best: 43.0421767 (2)	total: 203ms	remaining: 15s
#
# bestTest = 68.7454317
# bestIteration = 9
#
# 4:	loss: 68.7454317	best: 43.0421767 (2)	total: 213ms	remaining: 12.5s
#
# bestTest = 43.06949794
# bestIteration = 9
#
# 5:	loss: 43.0694979	best: 43.0421767 (2)	total: 222ms	remaining: 10.9s
#
# bestTest = 96.00547136
# bestIteration = 9
#
# 6:	loss: 96.0054714	best: 43.0421767 (2)	total: 232ms	remaining: 9.69s
#
# bestTest = 68.78252601
# bestIteration = 9
#
# 7:	loss: 68.7825260	best: 43.0421767 (2)	total: 241ms	remaining: 8.79s
#
# bestTest = 43.09679194
# bestIteration = 9
#
# 8:	loss: 43.0967919	best: 43.0421767 (2)	total: 250ms	remaining: 8.1s
#
# bestTest = 96.02909972
# bestIteration = 9
#
# 9:	loss: 96.0290997	best: 43.0421767 (2)	total: 260ms	remaining: 7.53s
#
# bestTest = 68.81937871
# bestIteration = 9
#
# 10:	loss: 68.8193787	best: 43.0421767 (2)	total: 269ms	remaining: 7.07s
#
# bestTest = 43.12405151
# bestIteration = 9
#
# 11:	loss: 43.1240515	best: 43.0421767 (2)	total: 278ms	remaining: 6.68s
#
# bestTest = 96.05261969
# bestIteration = 9
#
# 12:	loss: 96.0526197	best: 43.0421767 (2)	total: 287ms	remaining: 6.34s
#
# bestTest = 68.85599741
# bestIteration = 9
#
# 13:	loss: 68.8559974	best: 43.0421767 (2)	total: 297ms	remaining: 6.06s
#
# bestTest = 43.15127004
# bestIteration = 9
#
# 14:	loss: 43.1512700	best: 43.0421767 (2)	total: 306ms	remaining: 5.81s
#
# bestTest = 47.35436088
# bestIteration = 99
#
# 15:	loss: 47.3543609	best: 43.0421767 (2)	total: 380ms	remaining: 6.74s
#
# bestTest = 39.56593024
# bestIteration = 99
#
# 16:	loss: 39.5659302	best: 39.5659302 (16)	total: 480ms	remaining: 8s
#
# bestTest = 33.33782369
# bestIteration = 94
#
# 17:	loss: 33.3378237	best: 33.3378237 (17)	total: 555ms	remaining: 8.69s
#
# bestTest = 47.39414006
# bestIteration = 99
#
# 18:	loss: 47.3941401	best: 33.3378237 (17)	total: 634ms	remaining: 9.38s
#
# bestTest = 39.52683665
# bestIteration = 99
#
# 19:	loss: 39.5268366	best: 33.3378237 (17)	total: 710ms	remaining: 9.94s
#
# bestTest = 33.60452425
# bestIteration = 89
#
# 20:	loss: 33.6045243	best: 33.3378237 (17)	total: 805ms	remaining: 10.7s
#
# bestTest = 47.36132714
# bestIteration = 99
#
# 21:	loss: 47.3613271	best: 33.3378237 (17)	total: 887ms	remaining: 11.2s
#
# bestTest = 39.63912828
# bestIteration = 99
#
# 22:	loss: 39.6391283	best: 33.3378237 (17)	total: 994ms	remaining: 12s
#
# bestTest = 33.43006912
# bestIteration = 98
#
# 23:	loss: 33.4300691	best: 33.3378237 (17)	total: 1.1s	remaining: 12.6s
#
# bestTest = 47.43318669
# bestIteration = 99
#
# 24:	loss: 47.4331867	best: 33.3378237 (17)	total: 1.19s	remaining: 13.1s
#
# bestTest = 39.77081857
# bestIteration = 99
#
# 25:	loss: 39.7708186	best: 33.3378237 (17)	total: 1.28s	remaining: 13.5s
#
# bestTest = 33.33875261
# bestIteration = 96
#
# 26:	loss: 33.3387526	best: 33.3378237 (17)	total: 1.35s	remaining: 13.7s
#
# bestTest = 47.44239787
# bestIteration = 99
#
# 27:	loss: 47.4423979	best: 33.3378237 (17)	total: 1.46s	remaining: 14.1s
#
# bestTest = 39.90410277
# bestIteration = 99
#
# 28:	loss: 39.9041028	best: 33.3378237 (17)	total: 1.53s	remaining: 14.3s
#
# bestTest = 33.57161489
# bestIteration = 99
#
# 29:	loss: 33.5716149	best: 33.3378237 (17)	total: 1.63s	remaining: 14.7s
#
# bestTest = 94.92888111
# bestIteration = 9
#
# 30:	loss: 94.9288811	best: 33.3378237 (17)	total: 1.64s	remaining: 14.2s
#
# bestTest = 66.10023597
# bestIteration = 9
#
# 31:	loss: 66.1002360	best: 33.3378237 (17)	total: 1.65s	remaining: 13.8s
#
# bestTest = 39.73771597
# bestIteration = 9
#
# 32:	loss: 39.7377160	best: 33.3378237 (17)	total: 1.67s	remaining: 13.5s
#
# bestTest = 94.99724866
# bestIteration = 9
#
# 33:	loss: 94.9972487	best: 33.3378237 (17)	total: 1.68s	remaining: 13.1s
#
# bestTest = 66.40438081
# bestIteration = 9
#
# 34:	loss: 66.4043808	best: 33.3378237 (17)	total: 1.69s	remaining: 12.8s
#
# bestTest = 39.76778732
# bestIteration = 9
#
# 35:	loss: 39.7677873	best: 33.3378237 (17)	total: 1.7s	remaining: 12.5s
#
# bestTest = 95.06396187
# bestIteration = 9
#
# 36:	loss: 95.0639619	best: 33.3378237 (17)	total: 1.71s	remaining: 12.2s
#
# bestTest = 66.51080436
# bestIteration = 9
#
# 37:	loss: 66.5108044	best: 33.3378237 (17)	total: 1.73s	remaining: 11.9s
#
# bestTest = 39.81997393
# bestIteration = 9
#
# 38:	loss: 39.8199739	best: 33.3378237 (17)	total: 1.77s	remaining: 11.9s
#
# bestTest = 95.1291691
# bestIteration = 9
#
# 39:	loss: 95.1291691	best: 33.3378237 (17)	total: 1.79s	remaining: 11.6s
#
# bestTest = 66.61512072
# bestIteration = 9
#
# 40:	loss: 66.6151207	best: 33.3378237 (17)	total: 1.82s	remaining: 11.5s
#
# bestTest = 39.88258583
# bestIteration = 9
#
# 41:	loss: 39.8825858	best: 33.3378237 (17)	total: 1.83s	remaining: 11.2s
#
# bestTest = 95.19299212
# bestIteration = 9
#
# 42:	loss: 95.1929921	best: 33.3378237 (17)	total: 1.84s	remaining: 11s
#
# bestTest = 66.71747768
# bestIteration = 9
#
# 43:	loss: 66.7174777	best: 33.3378237 (17)	total: 1.86s	remaining: 10.8s
#
# bestTest = 39.95031496
# bestIteration = 9
#
# 44:	loss: 39.9503150	best: 33.3378237 (17)	total: 1.89s	remaining: 10.7s
#
# bestTest = 43.43454515
# bestIteration = 99
#
# 45:	loss: 43.4345451	best: 33.3378237 (17)	total: 2.08s	remaining: 11.5s
#
# bestTest = 34.90722189
# bestIteration = 99
#
# 46:	loss: 34.9072219	best: 33.3378237 (17)	total: 2.2s	remaining: 11.8s
#
# bestTest = 31.02601244
# bestIteration = 93
#
# 47:	loss: 31.0260124	best: 31.0260124 (47)	total: 2.38s	remaining: 12.5s
#
# bestTest = 43.66400783
# bestIteration = 99
#
# 48:	loss: 43.6640078	best: 31.0260124 (47)	total: 2.5s	remaining: 12.8s
#
# bestTest = 34.9031665
# bestIteration = 99
#
# 49:	loss: 34.9031665	best: 31.0260124 (47)	total: 2.64s	remaining: 13.2s
#
# bestTest = 31.1703021
# bestIteration = 61
#
# 50:	loss: 31.1703021	best: 31.0260124 (47)	total: 2.75s	remaining: 13.4s
#
# bestTest = 43.93263797
# bestIteration = 99
#
# 51:	loss: 43.9326380	best: 31.0260124 (47)	total: 2.85s	remaining: 13.6s
#
# bestTest = 35.0960309
# bestIteration = 99
#
# 52:	loss: 35.0960309	best: 31.0260124 (47)	total: 2.99s	remaining: 13.9s
#
# bestTest = 31.20349927
# bestIteration = 99
#
# 53:	loss: 31.2034993	best: 31.0260124 (47)	total: 3.15s	remaining: 14.3s
#
# bestTest = 44.12134658
# bestIteration = 99
#
# 54:	loss: 44.1213466	best: 31.0260124 (47)	total: 3.25s	remaining: 14.5s
#
# bestTest = 35.08428337
# bestIteration = 99
#
# 55:	loss: 35.0842834	best: 31.0260124 (47)	total: 3.35s	remaining: 14.6s
#
# bestTest = 31.27227308
# bestIteration = 95
#
# 56:	loss: 31.2722731	best: 31.0260124 (47)	total: 3.45s	remaining: 14.7s
#
# bestTest = 44.09639332
# bestIteration = 99
#
# 57:	loss: 44.0963933	best: 31.0260124 (47)	total: 3.55s	remaining: 14.8s
#
# bestTest = 35.22343863
# bestIteration = 99
#
# 58:	loss: 35.2234386	best: 31.0260124 (47)	total: 3.69s	remaining: 15.1s
#
# bestTest = 31.30610217
# bestIteration = 96
#
# 59:	loss: 31.3061022	best: 31.0260124 (47)	total: 3.82s	remaining: 15.3s
#
# bestTest = 94.42088581
# bestIteration = 9
#
# 60:	loss: 94.4208858	best: 31.0260124 (47)	total: 3.83s	remaining: 15s
#
# bestTest = 64.98635924
# bestIteration = 9
#
# 61:	loss: 64.9863592	best: 31.0260124 (47)	total: 3.85s	remaining: 14.8s
#
# bestTest = 36.79345236
# bestIteration = 9
#
# 62:	loss: 36.7934524	best: 31.0260124 (47)	total: 3.87s	remaining: 14.5s
#
# bestTest = 94.5414028
# bestIteration = 9
#
# 63:	loss: 94.5414028	best: 31.0260124 (47)	total: 3.88s	remaining: 14.3s
#
# bestTest = 65.16620736
# bestIteration = 9
#
# 64:	loss: 65.1662074	best: 31.0260124 (47)	total: 3.9s	remaining: 14.1s
#
# bestTest = 38.11881286
# bestIteration = 9
#
# 65:	loss: 38.1188129	best: 31.0260124 (47)	total: 3.91s	remaining: 13.9s
#
# bestTest = 94.52849263
# bestIteration = 9
#
# 66:	loss: 94.5284926	best: 31.0260124 (47)	total: 3.93s	remaining: 13.7s
#
# bestTest = 65.76805104
# bestIteration = 9
#
# 67:	loss: 65.7680510	best: 31.0260124 (47)	total: 3.94s	remaining: 13.5s
#
# bestTest = 37.44115059
# bestIteration = 9
#
# 68:	loss: 37.4411506	best: 31.0260124 (47)	total: 3.96s	remaining: 13.3s
#
# bestTest = 94.62601879
# bestIteration = 9
#
# 69:	loss: 94.6260188	best: 31.0260124 (47)	total: 3.98s	remaining: 13.1s
#
# bestTest = 65.72199979
# bestIteration = 9
#
# 70:	loss: 65.7219998	best: 31.0260124 (47)	total: 3.99s	remaining: 12.9s
#
# bestTest = 37.38310791
# bestIteration = 9
#
# 71:	loss: 37.3831079	best: 31.0260124 (47)	total: 4.01s	remaining: 12.7s
#
# bestTest = 94.71701863
# bestIteration = 9
#
# 72:	loss: 94.7170186	best: 31.0260124 (47)	total: 4.02s	remaining: 12.5s
#
# bestTest = 65.92054606
# bestIteration = 9
#
# 73:	loss: 65.9205461	best: 31.0260124 (47)	total: 4.04s	remaining: 12.3s
#
# bestTest = 37.41582656
# bestIteration = 9
#
# 74:	loss: 37.4158266	best: 31.0260124 (47)	total: 4.06s	remaining: 12.2s
#
# bestTest = 42.08309801
# bestIteration = 99
#
# 75:	loss: 42.0830980	best: 31.0260124 (47)	total: 4.23s	remaining: 12.5s
#
# bestTest = 32.9775695
# bestIteration = 99
#
# 76:	loss: 32.9775695	best: 31.0260124 (47)	total: 4.37s	remaining: 12.7s
#
# bestTest = 31.35259806
# bestIteration = 79
#
# 77:	loss: 31.3525981	best: 31.0260124 (47)	total: 4.51s	remaining: 12.8s
#
# bestTest = 42.1487633
# bestIteration = 99
#
# 78:	loss: 42.1487633	best: 31.0260124 (47)	total: 4.64s	remaining: 13s
#
# bestTest = 33.08316097
# bestIteration = 99
#
# 79:	loss: 33.0831610	best: 31.0260124 (47)	total: 4.8s	remaining: 13.2s
#
# bestTest = 30.16449191
# bestIteration = 94
#
# 80:	loss: 30.1644919	best: 30.1644919 (80)	total: 4.94s	remaining: 13.4s
#
# bestTest = 42.56310641
# bestIteration = 99
#
# 81:	loss: 42.5631064	best: 30.1644919 (80)	total: 5.07s	remaining: 13.5s
#
# bestTest = 33.99210345
# bestIteration = 99
#
# 82:	loss: 33.9921034	best: 30.1644919 (80)	total: 5.2s	remaining: 13.6s
#
# bestTest = 30.65124802
# bestIteration = 95
#
# 83:	loss: 30.6512480	best: 30.1644919 (80)	total: 5.37s	remaining: 13.8s
#
# bestTest = 42.63764479
# bestIteration = 99
#
# 84:	loss: 42.6376448	best: 30.1644919 (80)	total: 5.49s	remaining: 13.9s
#
# bestTest = 33.85188579
# bestIteration = 99
#
# 85:	loss: 33.8518858	best: 30.1644919 (80)	total: 5.62s	remaining: 14s
#
# bestTest = 30.98827607
# bestIteration = 85
#
# 86:	loss: 30.9882761	best: 30.1644919 (80)	total: 5.79s	remaining: 14.2s
#
# bestTest = 42.96486535
# bestIteration = 99
#
# 87:	loss: 42.9648654	best: 30.1644919 (80)	total: 5.92s	remaining: 14.3s
#
# bestTest = 33.94363122
# bestIteration = 98
#
# 88:	loss: 33.9436312	best: 30.1644919 (80)	total: 6.04s	remaining: 14.3s
#
# bestTest = 31.05436828
# bestIteration = 97
#
# 89:	loss: 31.0543683	best: 30.1644919 (80)	total: 6.17s	remaining: 14.4s
#
# bestTest = 95.24459089
# bestIteration = 9
#
# 90:	loss: 95.2445909	best: 30.1644919 (80)	total: 6.19s	remaining: 14.2s
#
# bestTest = 66.1754716
# bestIteration = 9
#
# 91:	loss: 66.1754716	best: 30.1644919 (80)	total: 6.2s	remaining: 14s
#
# bestTest = 38.66074345
# bestIteration = 9
#
# 92:	loss: 38.6607435	best: 30.1644919 (80)	total: 6.22s	remaining: 13.8s
#
# bestTest = 95.41700752
# bestIteration = 9
#
# 93:	loss: 95.4170075	best: 30.1644919 (80)	total: 6.24s	remaining: 13.7s
#
# bestTest = 66.64446056
# bestIteration = 9
#
# 94:	loss: 66.6444606	best: 30.1644919 (80)	total: 6.27s	remaining: 13.5s
#
# bestTest = 38.70543031
# bestIteration = 9
#
# 95:	loss: 38.7054303	best: 30.1644919 (80)	total: 6.29s	remaining: 13.4s
#
# bestTest = 95.56214204
# bestIteration = 9
#
# 96:	loss: 95.5621420	best: 30.1644919 (80)	total: 6.31s	remaining: 13.2s
#
# bestTest = 67.02050452
# bestIteration = 9
#
# 97:	loss: 67.0205045	best: 30.1644919 (80)	total: 6.32s	remaining: 13s
#
# bestTest = 38.57167033
# bestIteration = 9
#
# 98:	loss: 38.5716703	best: 30.1644919 (80)	total: 6.36s	remaining: 12.9s
#
# bestTest = 95.72923674
# bestIteration = 9
#
# 99:	loss: 95.7292367	best: 30.1644919 (80)	total: 6.38s	remaining: 12.8s
#
# bestTest = 67.34231431
# bestIteration = 9
#
# 100:	loss: 67.3423143	best: 30.1644919 (80)	total: 6.4s	remaining: 12.6s
#
# bestTest = 38.68216651
# bestIteration = 9
#
# 101:	loss: 38.6821665	best: 30.1644919 (80)	total: 6.42s	remaining: 12.5s
#
# bestTest = 95.844345
# bestIteration = 9
#
# 102:	loss: 95.8443450	best: 30.1644919 (80)	total: 6.43s	remaining: 12.3s
#
# bestTest = 67.62553598
# bestIteration = 9
#
# 103:	loss: 67.6255360	best: 30.1644919 (80)	total: 6.45s	remaining: 12.2s
#
# bestTest = 39.88107468
# bestIteration = 9
#
# 104:	loss: 39.8810747	best: 30.1644919 (80)	total: 6.47s	remaining: 12s
#
# bestTest = 41.13160072
# bestIteration = 99
#
# 105:	loss: 41.1316007	best: 30.1644919 (80)	total: 6.63s	remaining: 12.1s
#
# bestTest = 33.7310637
# bestIteration = 99
#
# 106:	loss: 33.7310637	best: 30.1644919 (80)	total: 6.82s	remaining: 12.3s
#
# bestTest = 33.65518436
# bestIteration = 90
#
# 107:	loss: 33.6551844	best: 30.1644919 (80)	total: 6.99s	remaining: 12.4s
#
# bestTest = 41.40500132
# bestIteration = 99
#
# 108:	loss: 41.4050013	best: 30.1644919 (80)	total: 7.15s	remaining: 12.5s
#
# bestTest = 34.51456292
# bestIteration = 98
#
# 109:	loss: 34.5145629	best: 30.1644919 (80)	total: 7.33s	remaining: 12.7s
#
# bestTest = 33.3356188
# bestIteration = 87
#
# 110:	loss: 33.3356188	best: 30.1644919 (80)	total: 7.5s	remaining: 12.8s
#
# bestTest = 41.68924728
# bestIteration = 99
#
# 111:	loss: 41.6892473	best: 30.1644919 (80)	total: 7.65s	remaining: 12.8s
#
# bestTest = 34.6168244
# bestIteration = 99
#
# 112:	loss: 34.6168244	best: 30.1644919 (80)	total: 7.88s	remaining: 13s
#
# bestTest = 32.88789137
# bestIteration = 90
#
# 113:	loss: 32.8878914	best: 30.1644919 (80)	total: 8.04s	remaining: 13.1s
#
# bestTest = 42.21774181
# bestIteration = 99
#
# 114:	loss: 42.2177418	best: 30.1644919 (80)	total: 8.22s	remaining: 13.2s
#
# bestTest = 34.83829839
# bestIteration = 99
#
# 115:	loss: 34.8382984	best: 30.1644919 (80)	total: 8.42s	remaining: 13.4s
#
# bestTest = 33.27617978
# bestIteration = 99
#
# 116:	loss: 33.2761798	best: 30.1644919 (80)	total: 8.58s	remaining: 13.4s
#
# bestTest = 42.56785265
# bestIteration = 99
#
# 117:	loss: 42.5678526	best: 30.1644919 (80)	total: 8.79s	remaining: 13.6s
#
# bestTest = 34.96094719
# bestIteration = 99
#
# 118:	loss: 34.9609472	best: 30.1644919 (80)	total: 9.09s	remaining: 13.8s
#
# bestTest = 34.67999449
# bestIteration = 99
#
# 119:	loss: 34.6799945	best: 30.1644919 (80)	total: 9.24s	remaining: 13.9s
#
# bestTest = 93.71433786
# bestIteration = 9
#
# 120:	loss: 93.7143379	best: 30.1644919 (80)	total: 9.27s	remaining: 13.7s
#
# bestTest = 63.26215616
# bestIteration = 9
#
# 121:	loss: 63.2621562	best: 30.1644919 (80)	total: 9.31s	remaining: 13.6s
#
# bestTest = 36.08653898
# bestIteration = 8
#
# 122:	loss: 36.0865390	best: 30.1644919 (80)	total: 9.34s	remaining: 13.4s
#
# bestTest = 94.03951972
# bestIteration = 9
#
# 123:	loss: 94.0395197	best: 30.1644919 (80)	total: 9.37s	remaining: 13.3s
#
# bestTest = 64.41226289
# bestIteration = 9
#
# 124:	loss: 64.4122629	best: 30.1644919 (80)	total: 9.4s	remaining: 13.2s
#
# bestTest = 36.56035955
# bestIteration = 8
#
# 125:	loss: 36.5603596	best: 30.1644919 (80)	total: 9.44s	remaining: 13s
#
# bestTest = 94.2375545
# bestIteration = 9
#
# 126:	loss: 94.2375545	best: 30.1644919 (80)	total: 9.46s	remaining: 12.9s
#
# bestTest = 64.49585825
# bestIteration = 9
#
# 127:	loss: 64.4958583	best: 30.1644919 (80)	total: 9.5s	remaining: 12.8s
#
# bestTest = 38.12122327
# bestIteration = 9
#
# 128:	loss: 38.1212233	best: 30.1644919 (80)	total: 9.53s	remaining: 12.6s
#
# bestTest = 94.41416261
# bestIteration = 9
#
# 129:	loss: 94.4141626	best: 30.1644919 (80)	total: 9.55s	remaining: 12.5s
#
# bestTest = 64.95272355
# bestIteration = 9
#
# 130:	loss: 64.9527236	best: 30.1644919 (80)	total: 9.57s	remaining: 12.3s
#
# bestTest = 37.35055818
# bestIteration = 9
#
# 131:	loss: 37.3505582	best: 30.1644919 (80)	total: 9.61s	remaining: 12.2s
#
# bestTest = 94.68404789
# bestIteration = 9
#
# 132:	loss: 94.6840479	best: 30.1644919 (80)	total: 9.64s	remaining: 12.1s
#
# bestTest = 65.58373765
# bestIteration = 9
#
# 133:	loss: 65.5837377	best: 30.1644919 (80)	total: 9.67s	remaining: 12s
#
# bestTest = 37.53693416
# bestIteration = 9
#
# 134:	loss: 37.5369342	best: 30.1644919 (80)	total: 9.71s	remaining: 11.9s
#
# bestTest = 39.60971645
# bestIteration = 99
#
# 135:	loss: 39.6097165	best: 30.1644919 (80)	total: 9.95s	remaining: 12s
#
# bestTest = 32.02651942
# bestIteration = 99
#
# 136:	loss: 32.0265194	best: 30.1644919 (80)	total: 10.2s	remaining: 12.2s
#
# bestTest = 31.00437339
# bestIteration = 40
#
# 137:	loss: 31.0043734	best: 30.1644919 (80)	total: 10.5s	remaining: 12.3s
#
# bestTest = 40.41070303
# bestIteration = 99
#
# 138:	loss: 40.4107030	best: 30.1644919 (80)	total: 10.7s	remaining: 12.4s
#
# bestTest = 31.95430667
# bestIteration = 98
#
# 139:	loss: 31.9543067	best: 30.1644919 (80)	total: 10.9s	remaining: 12.5s
#
# bestTest = 31.900106
# bestIteration = 47
#
# 140:	loss: 31.9001060	best: 30.1644919 (80)	total: 11.2s	remaining: 12.7s
#
# bestTest = 40.76923387
# bestIteration = 99
#
# 141:	loss: 40.7692339	best: 30.1644919 (80)	total: 11.5s	remaining: 12.7s
#
# bestTest = 32.5603533
# bestIteration = 99
#
# 142:	loss: 32.5603533	best: 30.1644919 (80)	total: 11.7s	remaining: 12.9s
#
# bestTest = 32.82284868
# bestIteration = 75
#
# 143:	loss: 32.8228487	best: 30.1644919 (80)	total: 11.9s	remaining: 12.9s
#
# bestTest = 41.14560089
# bestIteration = 99
#
# 144:	loss: 41.1456009	best: 30.1644919 (80)	total: 12.2s	remaining: 13s
#
# bestTest = 33.16243866
# bestIteration = 99
#
# 145:	loss: 33.1624387	best: 30.1644919 (80)	total: 12.4s	remaining: 13.1s
#
# bestTest = 31.61612568
# bestIteration = 94
#
# 146:	loss: 31.6161257	best: 30.1644919 (80)	total: 12.6s	remaining: 13.2s
#
# bestTest = 41.63724543
# bestIteration = 99
#
# 147:	loss: 41.6372454	best: 30.1644919 (80)	total: 12.9s	remaining: 13.2s
#
# bestTest = 33.5282923
# bestIteration = 99
#
# 148:	loss: 33.5282923	best: 30.1644919 (80)	total: 13.2s	remaining: 13.3s
#
# bestTest = 33.23928474
# bestIteration = 74
#
# 149:	loss: 33.2392847	best: 30.1644919 (80)	total: 13.3s	remaining: 13.3s
#
# bestTest = 93.84772317
# bestIteration = 9
#
# 150:	loss: 93.8477232	best: 30.1644919 (80)	total: 13.4s	remaining: 13.2s
#
# bestTest = 63.70228903
# bestIteration = 9
#
# 151:	loss: 63.7022890	best: 30.1644919 (80)	total: 13.4s	remaining: 13.1s
#
# bestTest = 34.97705131
# bestIteration = 9
#
# 152:	loss: 34.9770513	best: 30.1644919 (80)	total: 13.4s	remaining: 12.9s
#
# bestTest = 94.36386424
# bestIteration = 9
#
# 153:	loss: 94.3638642	best: 30.1644919 (80)	total: 13.5s	remaining: 12.8s
#
# bestTest = 65.00685332
# bestIteration = 9
#
# 154:	loss: 65.0068533	best: 30.1644919 (80)	total: 13.5s	remaining: 12.6s
#
# bestTest = 34.75112377
# bestIteration = 9
#
# 155:	loss: 34.7511238	best: 30.1644919 (80)	total: 13.5s	remaining: 12.5s
#
# bestTest = 94.6735198
# bestIteration = 9
#
# 156:	loss: 94.6735198	best: 30.1644919 (80)	total: 13.6s	remaining: 12.4s
#
# bestTest = 65.38370295
# bestIteration = 9
#
# 157:	loss: 65.3837029	best: 30.1644919 (80)	total: 13.6s	remaining: 12.2s
#
# bestTest = 36.76088434
# bestIteration = 9
#
# 158:	loss: 36.7608843	best: 30.1644919 (80)	total: 13.7s	remaining: 12.1s
#
# bestTest = 95.00091229
# bestIteration = 9
#
# 159:	loss: 95.0009123	best: 30.1644919 (80)	total: 13.7s	remaining: 12s
#
# bestTest = 65.99577771
# bestIteration = 9
#
# 160:	loss: 65.9957777	best: 30.1644919 (80)	total: 13.7s	remaining: 11.9s
#
# bestTest = 36.36107165
# bestIteration = 9
#
# 161:	loss: 36.3610716	best: 30.1644919 (80)	total: 13.8s	remaining: 11.7s
#
# bestTest = 95.3024095
# bestIteration = 9
#
# 162:	loss: 95.3024095	best: 30.1644919 (80)	total: 13.8s	remaining: 11.6s
#
# bestTest = 66.44262115
# bestIteration = 9
#
# 163:	loss: 66.4426211	best: 30.1644919 (80)	total: 13.8s	remaining: 11.5s
#
# bestTest = 38.09146966
# bestIteration = 9
#
# 164:	loss: 38.0914697	best: 30.1644919 (80)	total: 13.9s	remaining: 11.3s
#
# bestTest = 39.59704396
# bestIteration = 99
#
# 165:	loss: 39.5970440	best: 30.1644919 (80)	total: 14.2s	remaining: 11.4s
#
# bestTest = 32.22439726
# bestIteration = 96
#
# 166:	loss: 32.2243973	best: 30.1644919 (80)	total: 14.4s	remaining: 11.5s
#
# bestTest = 32.94822486
# bestIteration = 40
#
# 167:	loss: 32.9482249	best: 30.1644919 (80)	total: 14.7s	remaining: 11.5s
#
# bestTest = 40.32821206
# bestIteration = 99
#
# 168:	loss: 40.3282121	best: 30.1644919 (80)	total: 14.9s	remaining: 11.6s
#
# bestTest = 32.63899608
# bestIteration = 99
#
# 169:	loss: 32.6389961	best: 30.1644919 (80)	total: 15.3s	remaining: 11.7s
#
# bestTest = 31.77440967
# bestIteration = 61
#
# 170:	loss: 31.7744097	best: 30.1644919 (80)	total: 15.5s	remaining: 11.7s
#
# bestTest = 41.13196752
# bestIteration = 99
#
# 171:	loss: 41.1319675	best: 30.1644919 (80)	total: 15.8s	remaining: 11.8s
#
# bestTest = 33.56014916
# bestIteration = 99
#
# 172:	loss: 33.5601492	best: 30.1644919 (80)	total: 16.1s	remaining: 11.8s
#
# bestTest = 32.94799385
# bestIteration = 49
#
# 173:	loss: 32.9479938	best: 30.1644919 (80)	total: 16.5s	remaining: 11.9s
#
# bestTest = 41.70411696
# bestIteration = 99
#
# 174:	loss: 41.7041170	best: 30.1644919 (80)	total: 16.8s	remaining: 12s
#
# bestTest = 33.52251328
# bestIteration = 99
#
# 175:	loss: 33.5225133	best: 30.1644919 (80)	total: 17.2s	remaining: 12.1s
#
# bestTest = 33.57822245
# bestIteration = 55
#
# 176:	loss: 33.5782225	best: 30.1644919 (80)	total: 17.6s	remaining: 12.2s
#
# bestTest = 42.16601853
# bestIteration = 99
#
# 177:	loss: 42.1660185	best: 30.1644919 (80)	total: 18s	remaining: 12.3s
#
# bestTest = 34.17642858
# bestIteration = 99
#
# 178:	loss: 34.1764286	best: 30.1644919 (80)	total: 18.2s	remaining: 12.3s
#
# bestTest = 33.81798486
# bestIteration = 88
#
# 179:	loss: 33.8179849	best: 30.1644919 (80)	total: 18.6s	remaining: 12.4s
#
# bestTest = 94.03436594
# bestIteration = 9
#
# 180:	loss: 94.0343659	best: 30.1644919 (80)	total: 18.6s	remaining: 12.2s
#
# bestTest = 62.54035269
# bestIteration = 9
#
# 181:	loss: 62.5403527	best: 30.1644919 (80)	total: 18.7s	remaining: 12.1s
#
# bestTest = 34.6651656
# bestIteration = 9
#
# 182:	loss: 34.6651656	best: 30.1644919 (80)	total: 18.7s	remaining: 12s
#
# bestTest = 94.68242846
# bestIteration = 9
#
# 183:	loss: 94.6824285	best: 30.1644919 (80)	total: 18.8s	remaining: 11.8s
#
# bestTest = 64.60821354
# bestIteration = 9
#
# 184:	loss: 64.6082135	best: 30.1644919 (80)	total: 18.8s	remaining: 11.7s
#
# bestTest = 35.29022872
# bestIteration = 9
#
# 185:	loss: 35.2902287	best: 30.1644919 (80)	total: 18.9s	remaining: 11.6s
#
# bestTest = 95.03729477
# bestIteration = 9
#
# 186:	loss: 95.0372948	best: 30.1644919 (80)	total: 18.9s	remaining: 11.4s
#
# bestTest = 65.66407322
# bestIteration = 9
#
# 187:	loss: 65.6640732	best: 30.1644919 (80)	total: 19s	remaining: 11.3s
#
# bestTest = 36.18570428
# bestIteration = 9
#
# 188:	loss: 36.1857043	best: 30.1644919 (80)	total: 19s	remaining: 11.2s
#
# bestTest = 95.45702285
# bestIteration = 9
#
# 189:	loss: 95.4570228	best: 30.1644919 (80)	total: 19.1s	remaining: 11s
#
# bestTest = 66.23634638
# bestIteration = 9
#
# 190:	loss: 66.2363464	best: 30.1644919 (80)	total: 19.1s	remaining: 10.9s
#
# bestTest = 38.25669634
# bestIteration = 9
#
# 191:	loss: 38.2566963	best: 30.1644919 (80)	total: 19.2s	remaining: 10.8s
#
# bestTest = 95.76178668
# bestIteration = 9
#
# 192:	loss: 95.7617867	best: 30.1644919 (80)	total: 19.2s	remaining: 10.7s
#
# bestTest = 67.38933484
# bestIteration = 9
#
# 193:	loss: 67.3893348	best: 30.1644919 (80)	total: 19.3s	remaining: 10.5s
#
# bestTest = 38.96911504
# bestIteration = 9
#
# 194:	loss: 38.9691150	best: 30.1644919 (80)	total: 19.3s	remaining: 10.4s
#
# bestTest = 39.52080237
# bestIteration = 99
#
# 195:	loss: 39.5208024	best: 30.1644919 (80)	total: 19.9s	remaining: 10.6s
#
# bestTest = 32.51799573
# bestIteration = 98
#
# 196:	loss: 32.5179957	best: 30.1644919 (80)	total: 20.4s	remaining: 10.7s
#
# bestTest = 32.58047283
# bestIteration = 58
#
# 197:	loss: 32.5804728	best: 30.1644919 (80)	total: 20.8s	remaining: 10.7s
#
# bestTest = 41.046811
# bestIteration = 99
#
# 198:	loss: 41.0468110	best: 30.1644919 (80)	total: 21.3s	remaining: 10.8s
#
# bestTest = 32.9959191
# bestIteration = 99
#
# 199:	loss: 32.9959191	best: 30.1644919 (80)	total: 21.7s	remaining: 10.8s
#
# bestTest = 32.1363885
# bestIteration = 44
#
# 200:	loss: 32.1363885	best: 30.1644919 (80)	total: 22.1s	remaining: 10.9s
#
# bestTest = 42.16871188
# bestIteration = 99
#
# 201:	loss: 42.1687119	best: 30.1644919 (80)	total: 22.5s	remaining: 10.9s
#
# bestTest = 33.17621625
# bestIteration = 98
#
# 202:	loss: 33.1762163	best: 30.1644919 (80)	total: 22.9s	remaining: 10.9s
#
# bestTest = 33.1996123
# bestIteration = 64
#
# 203:	loss: 33.1996123	best: 30.1644919 (80)	total: 23.3s	remaining: 11s
#
# bestTest = 43.32132028
# bestIteration = 99
#
# 204:	loss: 43.3213203	best: 30.1644919 (80)	total: 23.7s	remaining: 11s
#
# bestTest = 33.35827788
# bestIteration = 99
#
# 205:	loss: 33.3582779	best: 30.1644919 (80)	total: 24.1s	remaining: 11s
#
# bestTest = 33.52867944
# bestIteration = 99
#
# 206:	loss: 33.5286794	best: 30.1644919 (80)	total: 24.5s	remaining: 11s
#
# bestTest = 43.37271293
# bestIteration = 99
#
# 207:	loss: 43.3727129	best: 30.1644919 (80)	total: 24.9s	remaining: 11s
#
# bestTest = 34.27908723
# bestIteration = 98
#
# 208:	loss: 34.2790872	best: 30.1644919 (80)	total: 25.3s	remaining: 11s
#
# bestTest = 34.02645678
# bestIteration = 94
#
# 209:	loss: 34.0264568	best: 30.1644919 (80)	total: 25.7s	remaining: 11s
#
# bestTest = 94.07688814
# bestIteration = 9
#
# 210:	loss: 94.0768881	best: 30.1644919 (80)	total: 25.7s	remaining: 10.9s
#
# bestTest = 63.16703056
# bestIteration = 9
#
# 211:	loss: 63.1670306	best: 30.1644919 (80)	total: 25.8s	remaining: 10.7s
#
# bestTest = 34.78614332
# bestIteration = 9
#
# 212:	loss: 34.7861433	best: 30.1644919 (80)	total: 25.9s	remaining: 10.6s
#
# bestTest = 95.43841974
# bestIteration = 9
#
# 213:	loss: 95.4384197	best: 30.1644919 (80)	total: 26s	remaining: 10.4s
#
# bestTest = 65.34247078
# bestIteration = 9
#
# 214:	loss: 65.3424708	best: 30.1644919 (80)	total: 26.1s	remaining: 10.3s
#
# bestTest = 35.05463063
# bestIteration = 9
#
# 215:	loss: 35.0546306	best: 30.1644919 (80)	total: 26.1s	remaining: 10.2s
#
# bestTest = 96.12512076
# bestIteration = 9
#
# 216:	loss: 96.1251208	best: 30.1644919 (80)	total: 26.2s	remaining: 10s
#
# bestTest = 66.33799395
# bestIteration = 9
#
# 217:	loss: 66.3379940	best: 30.1644919 (80)	total: 26.3s	remaining: 9.89s
#
# bestTest = 36.67614728
# bestIteration = 9
#
# 218:	loss: 36.6761473	best: 30.1644919 (80)	total: 26.4s	remaining: 9.76s
#
# bestTest = 96.60016119
# bestIteration = 9
#
# 219:	loss: 96.6001612	best: 30.1644919 (80)	total: 26.5s	remaining: 9.64s
#
# bestTest = 67.53340626
# bestIteration = 9
#
# 220:	loss: 67.5334063	best: 30.1644919 (80)	total: 26.6s	remaining: 9.5s
#
# bestTest = 36.72384561
# bestIteration = 9
#
# 221:	loss: 36.7238456	best: 30.1644919 (80)	total: 26.7s	remaining: 9.37s
#
# bestTest = 96.09998683
# bestIteration = 9
#
# 222:	loss: 96.0999868	best: 30.1644919 (80)	total: 26.7s	remaining: 9.23s
#
# bestTest = 68.55206659
# bestIteration = 9
#
# 223:	loss: 68.5520666	best: 30.1644919 (80)	total: 26.8s	remaining: 9.09s
#
# bestTest = 37.77414011
# bestIteration = 9
#
# 224:	loss: 37.7741401	best: 30.1644919 (80)	total: 26.9s	remaining: 8.97s
#
# bestTest = 40.24395445
# bestIteration = 99
#
# 225:	loss: 40.2439545	best: 30.1644919 (80)	total: 27.5s	remaining: 9.01s
#
# bestTest = 33.53313095
# bestIteration = 99
#
# 226:	loss: 33.5331310	best: 30.1644919 (80)	total: 28.1s	remaining: 9.05s
#
# bestTest = 33.79480237
# bestIteration = 17
#
# 227:	loss: 33.7948024	best: 30.1644919 (80)	total: 28.8s	remaining: 9.1s
#
# bestTest = 42.37136139
# bestIteration = 99
#
# 228:	loss: 42.3713614	best: 30.1644919 (80)	total: 29.5s	remaining: 9.15s
#
# bestTest = 34.67431926
# bestIteration = 97
#
# 229:	loss: 34.6743193	best: 30.1644919 (80)	total: 30.2s	remaining: 9.2s
#
# bestTest = 32.80685367
# bestIteration = 34
#
# 230:	loss: 32.8068537	best: 30.1644919 (80)	total: 30.9s	remaining: 9.23s
#
# bestTest = 43.25017174
# bestIteration = 99
#
# 231:	loss: 43.2501717	best: 30.1644919 (80)	total: 31.7s	remaining: 9.3s
#
# bestTest = 35.43790332
# bestIteration = 99
#
# 232:	loss: 35.4379033	best: 30.1644919 (80)	total: 32.6s	remaining: 9.37s
#
# bestTest = 33.56675525
# bestIteration = 73
#
# 233:	loss: 33.5667552	best: 30.1644919 (80)	total: 33.3s	remaining: 9.39s
#
# bestTest = 45.00830213
# bestIteration = 99
#
# 234:	loss: 45.0083021	best: 30.1644919 (80)	total: 34s	remaining: 9.39s
#
# bestTest = 35.96003646
# bestIteration = 98
#
# 235:	loss: 35.9600365	best: 30.1644919 (80)	total: 34.6s	remaining: 9.39s
#
# bestTest = 32.64553166
# bestIteration = 38
#
# 236:	loss: 32.6455317	best: 30.1644919 (80)	total: 35.3s	remaining: 9.38s
#
# bestTest = 44.05067924
# bestIteration = 99
#
# 237:	loss: 44.0506792	best: 30.1644919 (80)	total: 35.9s	remaining: 9.36s
#
# bestTest = 36.18159723
# bestIteration = 99
#
# 238:	loss: 36.1815972	best: 30.1644919 (80)	total: 36.6s	remaining: 9.35s
#
# bestTest = 33.20833694
# bestIteration = 99
#
# 239:	loss: 33.2083369	best: 30.1644919 (80)	total: 37.3s	remaining: 9.33s
#
# bestTest = 93.89986447
# bestIteration = 9
#
# 240:	loss: 93.8998645	best: 30.1644919 (80)	total: 37.5s	remaining: 9.18s
#
# bestTest = 63.60367653
# bestIteration = 9
#
# 241:	loss: 63.6036765	best: 30.1644919 (80)	total: 37.6s	remaining: 9.02s
#
# bestTest = 36.36035181
# bestIteration = 9
#
# 242:	loss: 36.3603518	best: 30.1644919 (80)	total: 37.8s	remaining: 8.86s
#
# bestTest = 94.8368989
# bestIteration = 9
#
# 243:	loss: 94.8368989	best: 30.1644919 (80)	total: 37.9s	remaining: 8.7s
#
# bestTest = 65.75399671
# bestIteration = 9
#
# 244:	loss: 65.7539967	best: 30.1644919 (80)	total: 38s	remaining: 8.54s
#
# bestTest = 37.585263
# bestIteration = 9
#
# 245:	loss: 37.5852630	best: 30.1644919 (80)	total: 38.2s	remaining: 8.38s
#
# bestTest = 95.27768368
# bestIteration = 9
#
# 246:	loss: 95.2776837	best: 30.1644919 (80)	total: 38.3s	remaining: 8.22s
#
# bestTest = 67.10177374
# bestIteration = 9
#
# 247:	loss: 67.1017737	best: 30.1644919 (80)	total: 38.5s	remaining: 8.06s
#
# bestTest = 39.02032759
# bestIteration = 9
#
# 248:	loss: 39.0203276	best: 30.1644919 (80)	total: 38.6s	remaining: 7.91s
#
# bestTest = 95.54793206
# bestIteration = 9
#
# 249:	loss: 95.5479321	best: 30.1644919 (80)	total: 38.7s	remaining: 7.74s
#
# bestTest = 68.14207257
# bestIteration = 9
#
# 250:	loss: 68.1420726	best: 30.1644919 (80)	total: 38.8s	remaining: 7.58s
#
# bestTest = 40.46132872
# bestIteration = 9
#
# 251:	loss: 40.4613287	best: 30.1644919 (80)	total: 39s	remaining: 7.43s
#
# bestTest = 95.9108916
# bestIteration = 9
#
# 252:	loss: 95.9108916	best: 30.1644919 (80)	total: 39.1s	remaining: 7.27s
#
# bestTest = 69.50142226
# bestIteration = 9
#
# 253:	loss: 69.5014223	best: 30.1644919 (80)	total: 39.3s	remaining: 7.11s
#
# bestTest = 39.05724477
# bestIteration = 9
#
# 254:	loss: 39.0572448	best: 30.1644919 (80)	total: 39.4s	remaining: 6.95s
#
# bestTest = 41.57233623
# bestIteration = 99
#
# 255:	loss: 41.5723362	best: 30.1644919 (80)	total: 40.7s	remaining: 7s
#
# bestTest = 34.9035336
# bestIteration = 95
#
# 256:	loss: 34.9035336	best: 30.1644919 (80)	total: 41.9s	remaining: 7.02s
#
# bestTest = 34.62593141
# bestIteration = 24
#
# 257:	loss: 34.6259314	best: 30.1644919 (80)	total: 43.2s	remaining: 7.03s
#
# bestTest = 44.42245369
# bestIteration = 99
#
# 258:	loss: 44.4224537	best: 30.1644919 (80)	total: 44.3s	remaining: 7.02s
#
# bestTest = 35.37241291
# bestIteration = 98
#
# 259:	loss: 35.3724129	best: 30.1644919 (80)	total: 45.5s	remaining: 7s
#
# bestTest = 35.67139295
# bestIteration = 27
#
# 260:	loss: 35.6713930	best: 30.1644919 (80)	total: 46.7s	remaining: 6.98s
#
# bestTest = 43.62057368
# bestIteration = 99
#
# 261:	loss: 43.6205737	best: 30.1644919 (80)	total: 47.9s	remaining: 6.94s
#
# bestTest = 36.45868342
# bestIteration = 99
#
# 262:	loss: 36.4586834	best: 30.1644919 (80)	total: 49s	remaining: 6.9s
#
# bestTest = 34.94629989
# bestIteration = 92
#
# 263:	loss: 34.9462999	best: 30.1644919 (80)	total: 50.3s	remaining: 6.86s
#
# bestTest = 44.89964473
# bestIteration = 99
#
# 264:	loss: 44.8996447	best: 30.1644919 (80)	total: 51.4s	remaining: 6.79s
#
# bestTest = 35.46184013
# bestIteration = 99
#
# 265:	loss: 35.4618401	best: 30.1644919 (80)	total: 52.6s	remaining: 6.72s
#
# bestTest = 36.17743895
# bestIteration = 36
#
# 266:	loss: 36.1774389	best: 30.1644919 (80)	total: 53.9s	remaining: 6.66s
#
# bestTest = 46.30754368
# bestIteration = 99
#
# 267:	loss: 46.3075437	best: 30.1644919 (80)	total: 55s	remaining: 6.57s
#
# bestTest = 37.14771399
# bestIteration = 99
#
# 268:	loss: 37.1477140	best: 30.1644919 (80)	total: 56.2s	remaining: 6.48s
#
# bestTest = 34.73118857
# bestIteration = 81
#
# 269:	loss: 34.7311886	best: 30.1644919 (80)	total: 57.4s	remaining: 6.38s
#
# bestTest = 95.09130192
# bestIteration = 9
#
# 270:	loss: 95.0913019	best: 30.1644919 (80)	total: 57.6s	remaining: 6.17s
#
# bestTest = 67.06688715
# bestIteration = 9
#
# 271:	loss: 67.0668871	best: 30.1644919 (80)	total: 57.9s	remaining: 5.96s
#
# bestTest = 40.22425898
# bestIteration = 9
#
# 272:	loss: 40.2242590	best: 30.1644919 (80)	total: 58.1s	remaining: 5.75s
#
# bestTest = 96.20904632
# bestIteration = 9
#
# 273:	loss: 96.2090463	best: 30.1644919 (80)	total: 58.4s	remaining: 5.54s
#
# bestTest = 68.07186252
# bestIteration = 9
#
# 274:	loss: 68.0718625	best: 30.1644919 (80)	total: 58.6s	remaining: 5.33s
#
# bestTest = 37.73807227
# bestIteration = 9
#
# 275:	loss: 37.7380723	best: 30.1644919 (80)	total: 58.9s	remaining: 5.12s
#
# bestTest = 96.31924449
# bestIteration = 9
#
# 276:	loss: 96.3192445	best: 30.1644919 (80)	total: 59.1s	remaining: 4.91s
#
# bestTest = 70.66944383
# bestIteration = 9
#
# 277:	loss: 70.6694438	best: 30.1644919 (80)	total: 59.4s	remaining: 4.7s
#
# bestTest = 39.89345608
# bestIteration = 9
#
# 278:	loss: 39.8934561	best: 30.1644919 (80)	total: 59.6s	remaining: 4.48s
#
# bestTest = 96.81993417
# bestIteration = 9
#
# 279:	loss: 96.8199342	best: 30.1644919 (80)	total: 59.8s	remaining: 4.27s
#
# bestTest = 72.2572527
# bestIteration = 9
#
# 280:	loss: 72.2572527	best: 30.1644919 (80)	total: 1m	remaining: 4.06s
#
# bestTest = 40.95656064
# bestIteration = 9
#
# 281:	loss: 40.9565606	best: 30.1644919 (80)	total: 1m	remaining: 3.85s
#
# bestTest = 97.72382645
# bestIteration = 9
#
# 282:	loss: 97.7238264	best: 30.1644919 (80)	total: 1m	remaining: 3.63s
#
# bestTest = 71.6667703
# bestIteration = 9
#
# 283:	loss: 71.6667703	best: 30.1644919 (80)	total: 1m	remaining: 3.42s
#
# bestTest = 43.73783941
# bestIteration = 9
#
# 284:	loss: 43.7378394	best: 30.1644919 (80)	total: 1m 1s	remaining: 3.21s
#
# bestTest = 42.74132368
# bestIteration = 99
#
# 285:	loss: 42.7413237	best: 30.1644919 (80)	total: 1m 3s	remaining: 3.09s
#
# bestTest = 36.41584993
# bestIteration = 98
#
# 286:	loss: 36.4158499	best: 30.1644919 (80)	total: 1m 5s	remaining: 2.96s
#
# bestTest = 38.15626682
# bestIteration = 28
#
# 287:	loss: 38.1562668	best: 30.1644919 (80)	total: 1m 7s	remaining: 2.82s
#
# bestTest = 43.76997691
# bestIteration = 99
#
# 288:	loss: 43.7699769	best: 30.1644919 (80)	total: 1m 10s	remaining: 2.66s
#
# bestTest = 36.81275149
# bestIteration = 99
#
# 289:	loss: 36.8127515	best: 30.1644919 (80)	total: 1m 12s	remaining: 2.5s
#
# bestTest = 35.7277692
# bestIteration = 41
#
# 290:	loss: 35.7277692	best: 30.1644919 (80)	total: 1m 14s	remaining: 2.31s
#
# bestTest = 45.46385809
# bestIteration = 99
#
# 291:	loss: 45.4638581	best: 30.1644919 (80)	total: 1m 16s	remaining: 2.11s
#
# bestTest = 38.52800719
# bestIteration = 99
#
# 292:	loss: 38.5280072	best: 30.1644919 (80)	total: 1m 19s	remaining: 1.9s
#
# bestTest = 36.34853859
# bestIteration = 75
#
# 293:	loss: 36.3485386	best: 30.1644919 (80)	total: 1m 21s	remaining: 1.67s
#
# bestTest = 45.87132541
# bestIteration = 99
#
# 294:	loss: 45.8713254	best: 30.1644919 (80)	total: 1m 24s	remaining: 1.42s
#
# bestTest = 38.27632002
# bestIteration = 99
#
# 295:	loss: 38.2763200	best: 30.1644919 (80)	total: 1m 26s	remaining: 1.16s
#
# bestTest = 37.62005407
# bestIteration = 44
#
# 296:	loss: 37.6200541	best: 30.1644919 (80)	total: 1m 28s	remaining: 895ms
#
# bestTest = 46.9021357
# bestIteration = 99
#
# 297:	loss: 46.9021357	best: 30.1644919 (80)	total: 1m 30s	remaining: 609ms
#
# bestTest = 39.24425609
# bestIteration = 99
#
# 298:	loss: 39.2442561	best: 30.1644919 (80)	total: 1m 33s	remaining: 311ms
#
# bestTest = 39.30100332
# bestIteration = 99
#
# 299:	loss: 39.3010033	best: 30.1644919 (80)	total: 1m 35s	remaining: 0us
# Estimating final quality...
# Training on fold [0/5]
#
# bestTest = 23.64092293
# bestIteration = 28
#
# Training on fold [1/5]
#
# bestTest = 23.85291459
# bestIteration = 97
#
# Training on fold [2/5]
#
# bestTest = 24.27438213
# bestIteration = 95
#
# Training on fold [3/5]
#
# bestTest = 25.4569629
# bestIteration = 79
#
# Training on fold [4/5]
#
# bestTest = 31.41639951
# bestIteration = 84
#
# Wall time: 1min 36s

# %%
cb_model = CatBoostRegressor(**grid_search_result['params'], random_state=1982, verbose=0)

# %% [markdown]
# 5. LightGBM

# %%
# %%time

model = LGBMRegressor(random_state=1982)
depth_range = list(range(1, 21))
est_range = [1, 3, 5, 10, 20, 100, 500, 1000]
speed_range = [0.03, 0.1, 0.5, 0.7, 1]
params = {'max_depth': depth_range, 'n_estimators': est_range, 'learning_rate': speed_range}
lgbm_model = RandomizedSearchCV(model, params, scoring='neg_root_mean_squared_error', verbose=1, cv=tscv, random_state=1982)
lgbm_model.fit(train_features, train_target)
lgbm_best_params1 = lgbm_model.best_params_
lgbm_best_params1
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Wall time: 16.2 s
# {'n_estimators': 100, 'max_depth': 16, 'learning_rate': 0.1}

# %%
lgbm_model = LGBMRegressor(**lgbm_best_params1, random_state=1982)

# %% [markdown]
# ## Тестирование

# %%
def model_fit(model):
    model.fit(train_features, train_target)

# %%
def model_test(model):
    test_predictions = model.predict(test_features)
    rmse = mean_squared_error(test_target, test_predictions, squared=False)
    return rmse

# %%
pd.set_option('max_colwidth', 120)

models = [tree_model, rf_model, lr_model, cb_model, lgbm_model]
results = []
for model in models:
    row = []
    l_time = %timeit -n1 -r1 -o model_fit(model);
    p_time = %timeit -n1 -r1 -o model_test(model);
    rmse = model_test(model)
    row.append(str(model))
    row.append(rmse)
    row.append(str(l_time)[:7])
    row.append(str(p_time)[:7])
    results.append(row)
results = pd.DataFrame(results, columns=['Model', 'RMSE', 'Learning_time', 'Predicting_time'])
results
# Out:
# 19.1 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 3.6 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 176 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 5.72 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 15.7 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 2.29 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 191 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 2.98 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 133 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 6.84 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
#                                                                      Model  \
# 0                    DecisionTreeRegressor(max_depth=8, random_state=1982)
# 1  RandomForestRegressor(max_depth=16, n_estimators=10, random_state=1982)
# 2                                                       LinearRegression()
# 3           <catboost.core.CatBoostRegressor object at 0x000001A4639D0B80>
# 4                           LGBMRegressor(max_depth=16, random_state=1982)
#
#    RMSE Learning_time Predicting_time
# 0 56.11       19.1 ms         3.6 ms
# 1 49.83       176 ms          5.72 ms
# 2 52.43       15.7 ms         2.29 ms
# 3 45.57       191 ms          2.98 ms
# 4 42.96       133 ms          6.84 ms

# %% [markdown]
# ## Общий вывод
#
# В результате иследования эффективности работы различных моделей можно сделать ряд выводов:
# * Наибольшую эффективность показывают модели бустинга. Остальные модели не смогли преодолеть порог в 48.
# * Наилучший показатель RMSE у модели LGBM, скорость обучения существенно выше чем у Catboost, однако по скорости предсказания выигрывает последний.
# * В ходе подбора параметров и последующих промежуточных тестирований было обнаружено, что при повышении количества отстающих признаков (lag) качество работы Случайного леса повышается и он преодолевает порог, а моделей бустинга незначительно снижается.
#
# * Catboost характеризуется повышенным временем подбора оптимальных гиперпараметров при использовании встроенного инструмента подбора
#
# Для предсказания спроса (количества заказов) на услуги такси на основании исторических данных мы рекомендуем использовать модель LGBM, как наиболее результативную (RMSE=43).
